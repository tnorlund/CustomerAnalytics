# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
customer_df = pd.read_csv(
    "Marketing_Customer_Value_Analysis.csv",
    index_col=0
)
churn_df = pd.read_csv(
    "Customer_Churn_Dataset.csv",
    index_col=0
)
customer_df.columns
# Out:
# Index(['State', 'Customer Lifetime Value', 'Response', 'Coverage', 'Education',
#        'Effective To Date', 'EmploymentStatus', 'Gender', 'Income',
#        'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %% [markdown]
# So in order to develop a model for calculating the Customer Lifetime Value, I first need to clean the data, this can be done by normalizing the values. Let's take each column individually.
#
# 1. State
#
# We really only have 5 unique states found in the

# %%
customer_df["State"].unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#       dtype=object)

# %%
customer_df[
    [
        'Customer Lifetime Value', 
        'Income', 'Monthly Premium Auto', 
        'Months Since Last Claim', 
        'Months Since Policy Inception',
        'Number of Open Complaints',
        'Number of Policies',
        'Total Claim Amount'
    ]
].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_07a76ab2_1533_11ea_8fb4_784f435c79f3row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_07a76ab2_1533_11ea_8fb4_784f435c79f3row0_col1 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_07a76ab2_1533_11ea_8fb4_784f435c79f3row0_col2 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_07a76ab2_1533_11ea_8fb4_784f435c79f3row0_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_07a76ab2_1533_11ea_8fb4_784f435c79f3row0_col4 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_07a76ab2_1533_11ea_8fb4_784f435c79f3row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_07a76ab2_1533_11ea_8fb4_784f435c79f3row0_col6 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
# ...

# %%
customer_df["Customer Lifetime Value"].plot.kde()
